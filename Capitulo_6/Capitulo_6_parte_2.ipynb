# %% [markdown]
# USGS
# https://www.youtube.com/watch?v=dMA9pYiwZh4&ab_channel=GeoCositasParaDummies
# https://www.linkedin.com/in/ingjuanmasuarez/

# %%
import requests
import folium

# %%
url = "https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/4.5_hour.geojson"
terremotos = requests.get(url).json()

# %%
print(terremotos)
# Out:
# {'type': 'FeatureCollection', 'metadata': {'generated': 1715287038000, 'url': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/4.5_hour.geojson', 'title': 'USGS Magnitude 4.5+ Earthquakes, Past Hour', 'status': 200, 'api': '1.10.3', 'count': 0}, 'features': []}

# %%
mapa = folium.Map(location=(0,0),zoom_start=2)
for terremoto in terremotos["features"]:
    coordenadas = terremoto["geometry"]["coordinates"]
    lugar = terremoto["properties"]["place"]
    magnitude = terremoto["properties"]["mag"]

    folium.Marker(
        location = [coordenadas[1], coordenadas[0]],
        popup = f"Lugar: {lugar}, Magnitud: {magnitude}",
    ).add_to(mapa)

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
