# %%
#Variables del código
tamiz_200 = 2
tamiz_4 = 60
Cu = 3
Cc = 2

#Desarrollo del código
if tamiz_200 > 50 :
  print("Mundo de los finos")
else:
  if tamiz_4 > 50:
    if 0<tamiz_200<5:
      if Cu >= 6 and 1<=Cc<=3:
        print("SW")
      else:
        print("SP")
    elif 5<tamiz_200<12:
      if Cu >= 6 and 1<=Cc<=3:
        print("SW")
        #cartaPlasticidad()
      else:
        print("SP")
        #cartaPlasticidad()
    else:
      print("S")
      #cartaPlasticidad()
  else:
    print("Mundo de las Gravas")
# Out:
# SP
